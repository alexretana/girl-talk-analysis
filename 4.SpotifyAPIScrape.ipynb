# %%
import pandas as pd
import requests
import base64
from urllib.parse import urlencode
import json
import datetime

#import constants from KEYS module. create a module called KEYS.py and Add your own Client ID and Client Secret to it
import KEYS

# %%
songs_df = pd.read_csv('./data/artistAndTracks.csv', index_col=[0])

# %%
#for testing
songs_df = songs_df[:5]

# %%
songs_df
# Out:
#                                              artist  \
# 0                                     Black Sabbath
# 1                                          The Pack
# 2                                            M.I.A.
# 3                                       Jimmy Smith
# 4                                          Dorrough
# ..                                              ...
# 341  Krave featuring Flo Rida, Pitbull, and Lil Jon
# 342                                            T.I.
# 343          Rosalind Rice featuring French Montana
# 344                          The Edgar Winter Group
# 345                       DMX featuring Sheek Louch
#
#                                           track
# 0                                      War Pigs
# 1                            This Shit Slappin'
# 2                                  Paper Planes
# 3    I'm Gonna Love You Just a Little More Babe
# 4                           Ice Cream Paint Job
# ..                                          ...
# 341                                    Go Crazy
# 342                              Rubberband Man
# 343                                     Hustler
# 344                                Frankenstein
# 345                               Get at Me Dog
#
# [346 rows x 2 columns]

# %%
#assign keys to values here

client_id = KEYS.CLIENT_ID
client_secret = KEYS.CLIENT_SECRET

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentiatls(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentiatls()
        return  {
            "Authorization" : f"Basic {client_creds_b64}",
        }
    
    def get_token_data(self):
        return {
            "grant_type":"client_credentials",
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_headers = self.get_token_headers()
        token_data = self.get_token_data()
        r = requests.post(token_url, headers=token_headers, data=token_data)
        if r.status_code not in range(200,299):
            raise Exception("Could not Authenticate client")
            #return False
        data = r.json() #convert json to dict
        now = datetime.datetime.now() # create datetime obj for now
        access_token = data['access_token'] #retrieve token from response
        expires_in = data['expires_in'] #retrieve token lifetime
        print(expires_in)
        expires = now + datetime.timedelta(seconds=expires_in) #creates datetime for when token expires
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < datetime.datetime.now() #boolean to rep if expired
        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token

    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers


    def get_resources(self, lookup_id, resource_type = 'albums', version = 'v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range (200,299):
            return {}
        return r.json()


    def get_album(self, _id):
        return self.get_resources(_id, resource_type= 'albums')

    def get_artist(self, _id):
        return self.get_resources(_id, resource_type= 'artists')


    def base_search(self, query_params):
        headers = self.get_resource_header()
        
        endpoint = "https://api.spotify.com/v1/search"
        r = requests.get(endpoint, params=query_params, headers=headers)
         
        print(r.url)
        if r.status_code in range(200,299):
            return r.json()
        return {}

    def search(self, query=None, search_type = 'artist'):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query, dict):
            query = " ".join([f'{k}:{v}' for k,v in query.items()])
        query_params = {
            "q":query,
            "type":search_type.lower()
        }
        
        return self.base_search(query_params)

# %%
client = SpotifyAPI(client_id, client_secret)

# %%
query = {
    "artist" : songs_df.loc[0,'artist'],
    "track" : songs_df.loc[0,'track']
}
tracks = client.search(query, search_type='track')

track_uri = tracks['tracks']['items'][0]['uri']
# Out:
# https://api.spotify.com/v1/search?q=artist%3ABlack+Sabbath+track%3AWar+Pigs&type=track

# %%
tracks['tracks']['items'][0]['uri']
# Out:
# 'spotify:track:2rd9ETlulTbz6BYZcdvIE1'

# %%
songs_df['track_uri'] = ""

for idx, row in songs_df.iterrows():

    query = {
        "artist" : row['artist'],
        "track" : row['track']
    }
    tracks = client.search(query, search_type='track')
    
    try:
        track_uri = tracks['tracks']['items'][0]['uri']
        
    except(IndexError) as e:
        #update search params
        halfLen = len(row['track'])//2
        query.update({'track': row['track'][:halfLen]})
        del query['artist']
        #hit api again
        tracks = client.search(query, search_type='track')
        try:
            track_uri = tracks['tracks']['items'][0]['uri']
            
        except:
            
            query.update({'track':row['track'].split('"')[0]})
            
            tracks = client.search(query, search_type='track')
            try:
                track_uri = tracks['tracks']['items'][0]['uri']
            except:
                track_uri= ""
    
    songs_df.loc[idx, 'track_uri'] = track_uri
# Out:
# https://api.spotify.com/v1/search?q=artist%3ABlack+Sabbath+track%3AWar+Pigs&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Pack+track%3AThis+Shit+Slappin%27&type=track
# https://api.spotify.com/v1/search?q=track%3AThis+Shit&type=track
# https://api.spotify.com/v1/search?q=artist%3AM.I.A.+track%3APaper+Planes&type=track
# https://api.spotify.com/v1/search?q=artist%3AJimmy+Smith+track%3AI%27m+Gonna+Love+You+Just+a+Little+More+Babe&type=track
# https://api.spotify.com/v1/search?q=track%3AI%27m+Gonna+Love+You+Ju&type=track
# https://api.spotify.com/v1/search?q=artist%3ADorrough+track%3AIce+Cream+Paint+Job&type=track
# https://api.spotify.com/v1/search?q=artist%3AJ-Kwon+track%3ATipsy+%2709&type=track
# https://api.spotify.com/v1/search?q=artist%3AN.W.A+track%3AAppetite+for+Destruction%22+%28portion+sampled+samples+%22Get+Me+Back+on+Time%2C+Engine+%239%22+by+Wilson+Pickett%29&type=track
# https://api.spotify.com/v1/search?q=track%3AAppetite+for+Destruction%22+%28portion+sampled+samples+&type=track
# https://api.spotify.com/v1/search?q=track%3AAppetite+for+Destruction&type=track
# https://api.spotify.com/v1/search?q=artist%3AOl%27+Dirty+Bastard+track%3AShimmy+Shimmy+Ya&type=track
# https://api.spotify.com/v1/search?q=track%3AShimmy+S&type=track
# https://api.spotify.com/v1/search?q=artist%3APrince+track%3ADelirious&type=track
# https://api.spotify.com/v1/search?q=artist%3ABeastie+Boys+track%3AHey+Ladies&type=track
# https://api.spotify.com/v1/search?q=artist%3AMr.+Cheeks+featuring+Missy+Elliot%2C+Diddy%2C+and+Petey+Pablo+track%3ALights%2C+Camera%2C+Action%21+%28Remix%29&type=track
# https://api.spotify.com/v1/search?q=track%3ALights%2C+Camera%2C&type=track
# https://api.spotify.com/v1/search?q=artist%3ABananarama+track%3ACruel+Summer&type=track
# https://api.spotify.com/v1/search?q=artist%3AGenesis+track%3ATonight%2C+Tonight%2C+Tonight&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Jackson+5+track%3AI+Want+You+Back&type=track
# https://api.spotify.com/v1/search?q=artist%3ABeastie+Boys+track%3AIntergalactic%22+%28portion+sampled+samples+%22The+New+Style%22+by+Beastie+Boys%29&type=track
# https://api.spotify.com/v1/search?q=track%3AIntergalactic%22+%28portion+sampled+samp&type=track
# https://api.spotify.com/v1/search?q=track%3AIntergalactic&type=track
# https://api.spotify.com/v1/search?q=artist%3ASimon+and+Garfunkel+track%3ACecilia&type=track
# https://api.spotify.com/v1/search?q=artist%3AMain+Source+track%3ALooking+at+the+Front+Door&type=track
# https://api.spotify.com/v1/search?q=artist%3AJames+Brown+track%3AFunky+Drummer&type=track
# https://api.spotify.com/v1/search?q=artist%3ALudacris+featring+Lil+Scrappy+track%3AEverybody+Drunk%22+%28portion+sampled+samples+%22You+Don%27t+Want+Drama%22+by+8Ball+%26+MJG%29&type=track
# https://api.spotify.com/v1/search?q=track%3AEverybody+Drunk%22+%28portion+sampled+sample&type=track
# https://api.spotify.com/v1/search?q=track%3AEverybody+Drunk&type=track
# https://api.spotify.com/v1/search?q=artist%3ARobert+Palmer+track%3AAddicted+to+Love&type=track
# https://api.spotify.com/v1/search?q=artist%3ADJ+OGB+featuring+Francisco+and+Gemeni+track%3AHands+Up&type=track
# https://api.spotify.com/v1/search?q=track%3AHand&type=track
# https://api.spotify.com/v1/search?q=artist%3ALady+Gaga+track%3ABad+Romance&type=track
# https://api.spotify.com/v1/search?q=artist%3AGeorge+Clinton+track%3AAtomic+Dog&type=track
# https://api.spotify.com/v1/search?q=artist%3AKraftwerk+track%3AIt%27s+More+Fun+to+Compute&type=track
# https://api.spotify.com/v1/search?q=artist%3ABlack+Eyed+Peas+track%3ABoom+Boom+Pow&type=track
# https://api.spotify.com/v1/search?q=artist%3AGucci+Mane+featuring+Usher+track%3ASpotlight&type=track
# https://api.spotify.com/v1/search?q=track%3ASpot&type=track
# https://api.spotify.com/v1/search?q=artist%3AStarpoint+track%3AObject+of+My+Desire&type=track
# https://api.spotify.com/v1/search?q=artist%3AOutkast+featuring+Sleepy+Brown+track%3AThe+Way+You+Move&type=track
# https://api.spotify.com/v1/search?q=track%3AThe+Way+&type=track
# https://api.spotify.com/v1/search?q=artist%3AMGMT+track%3AKids&type=track
# https://api.spotify.com/v1/search?q=artist%3AAfro-Rican+track%3AGive+It+All+You+Got+%28Doggy+Style%29&type=track
# https://api.spotify.com/v1/search?q=track%3AGive+It+All+You+&type=track
# https://api.spotify.com/v1/search?q=artist%3ADominique+Young+Unique+track%3AShow+My+Ass&type=track
# https://api.spotify.com/v1/search?q=track%3AShow+&type=track
# https://api.spotify.com/v1/search?q=artist%3AT.+Rex+track%3A20th+Century+Boy&type=track
# https://api.spotify.com/v1/search?q=artist%3AKylie+Minogue+track%3ACan%27t+Get+You+Out+of+My+Head&type=track
# https://api.spotify.com/v1/search?q=track%3ACan%27t+Get+You+&type=track
# https://api.spotify.com/v1/search?q=artist%3ATrick+Daddy+featuring+The+Slip-N-Slide+Express+track%3ATake+It+to+Da+House&type=track
# https://api.spotify.com/v1/search?q=track%3ATake+It+t&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Temptations+track%3AGet+Ready&type=track
# https://api.spotify.com/v1/search?q=artist%3AT.I.+featuring+Keri+Hilson+track%3AGot+Your+Back&type=track
# https://api.spotify.com/v1/search?q=track%3AGot+Yo&type=track
# https://api.spotify.com/v1/search?q=artist%3ABirdman+featuring+Drake+and+Lil+Wayne+track%3AMoney+to+Blow&type=track
# https://api.spotify.com/v1/search?q=track%3AMoney+&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Isley+Brothers+track%3AShout&type=track
# https://api.spotify.com/v1/search?q=artist%3ABlue+Oyster+Cult+track%3A%28Don%27t+Fear%29+the+Reaper&type=track
# https://api.spotify.com/v1/search?q=track%3A%28Don%27t+Fear&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Cars+track%3AMoving+in+Stereo&type=track
# https://api.spotify.com/v1/search?q=artist%3AN.E.R.D+track%3AEveryone+Nose+%28All+the+Girls+Standing+in+the+Line+for+the+Bathroom%29&type=track
# https://api.spotify.com/v1/search?q=artist%3ABone+Thugs-n-Harmony+track%3A1st+of+tha+Month&type=track
# https://api.spotify.com/v1/search?q=artist%3ADrake+track%3AOver&type=track
# https://api.spotify.com/v1/search?q=artist%3ALudacris+track%3AHow+Low%22+%28portion+sampled+samples+%22Bring+the+Noise%22+by+Public+Enemy%29&type=track
# https://api.spotify.com/v1/search?q=track%3AHow+Low%22+%28portion+sampled+samples+&type=track
# https://api.spotify.com/v1/search?q=track%3AHow+Low&type=track
# https://api.spotify.com/v1/search?q=artist%3ADevo+track%3AGates+of+Steel&type=track
# https://api.spotify.com/v1/search?q=artist%3AWiz+Khalifa+track%3ABlack+and+Yellow&type=track
# https://api.spotify.com/v1/search?q=artist%3AFine+Young+Cannibals+track%3AGood+Thing+%28Prince+Paul+remix%29&type=track
# https://api.spotify.com/v1/search?q=track%3AGood+Thing+%28Pri&type=track
# https://api.spotify.com/v1/search?q=artist%3AModern+English+track%3AI+Melt+with+You&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Clash+track%3AShould+I+Stay+or+Should+I+Go&type=track
# https://api.spotify.com/v1/search?q=artist%3ACream+track%3ASunshine+of+Your+Love&type=track
# https://api.spotify.com/v1/search?q=artist%3AKesha+track%3ATik+Tok&type=track
# https://api.spotify.com/v1/search?q=artist%3ADaft+Punk+track%3ATelevision+Rules+the+Nation&type=track
# https://api.spotify.com/v1/search?q=artist%3ASteve+Miller+Band+track%3AJungle+Love&type=track
# https://api.spotify.com/v1/search?q=artist%3ADepeche+Mode+track%3AJust+Can%27t+Get+Enough&type=track
# https://api.spotify.com/v1/search?q=artist%3AKaty+Perry+featuring+Snoop+Dogg+track%3ACalifornia+Gurls&type=track
# https://api.spotify.com/v1/search?q=track%3ACaliforn&type=track
# https://api.spotify.com/v1/search?q=artist%3AFree+School+featuring+Kelis+and+apl.de.ap+track%3AGrey+Goose+%28Whatcha+Sippin%27+On%29&type=track
# https://api.spotify.com/v1/search?q=track%3AGrey+Goose+%28Wha&type=track
# https://api.spotify.com/v1/search?q=artist%3ABelinda+Carlisle+track%3AHeaven+Is+a+Place+on+Earth&type=track
# https://api.spotify.com/v1/search?q=artist%3AJanet+Jackson+track%3ASomeone+to+Call+My+Lover&type=track
# https://api.spotify.com/v1/search?q=artist%3AMSTRKRFT+featuring+N.O.R.E.+track%3ABounce&type=track
# https://api.spotify.com/v1/search?q=track%3ABou&type=track
# https://api.spotify.com/v1/search?q=artist%3AShorty+Long+track%3AFunction+at+the+Junction&type=track
# https://api.spotify.com/v1/search?q=artist%3ADuke+Williams+and+the+Extremes+track%3AChinese+Chicken&type=track
# https://api.spotify.com/v1/search?q=artist%3A2+Live+Crew+track%3AGet+It+Girl&type=track
# https://api.spotify.com/v1/search?q=artist%3AYoung+Dro+featuring+T.I.+and+Gucci+Mane+track%3AFreeze+Me&type=track
# https://api.spotify.com/v1/search?q=track%3AFree&type=track
# https://api.spotify.com/v1/search?q=artist%3AGinuwine+track%3APony&type=track
# https://api.spotify.com/v1/search?q=artist%3AYeah+Yeah+Yeahs+track%3AHeads+Will+Roll&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Ting+Tings+track%3AThat%27s+Not+My+Name&type=track
# https://api.spotify.com/v1/search?q=artist%3AJ.+Cole+track%3ABlow+Up&type=track
# https://api.spotify.com/v1/search?q=track%3ABlo&type=track
# https://api.spotify.com/v1/search?q=artist%3AJ-Kwon+track%3AYeah&type=track
# https://api.spotify.com/v1/search?q=artist%3AGeorge+Harrison+track%3AGot+My+Mind+Set+on+You&type=track
# https://api.spotify.com/v1/search?q=artist%3AThree+6+Mafia+track%3AWho+Run+It&type=track
# https://api.spotify.com/v1/search?q=artist%3ADiamond+track%3ALotta+Money&type=track
# https://api.spotify.com/v1/search?q=artist%3APublic+Enemy+track%3ABring+the+Noise&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Young+Rascals+track%3AGood+Lovin%27&type=track
# https://api.spotify.com/v1/search?q=artist%3AT-No+featuring+Slick+Rick+track%3AFucked+Up&type=track
# https://api.spotify.com/v1/search?q=track%3AFuck&type=track
# https://api.spotify.com/v1/search?q=artist%3ALil+Wil+track%3ABust+It+Open&type=track
# https://api.spotify.com/v1/search?q=artist%3AJane%27s+Addiction+track%3AJane+Says&type=track
# https://api.spotify.com/v1/search?q=artist%3ATrina+featuring+Killer+Mike+track%3ALook+Back+at+Me&type=track
# https://api.spotify.com/v1/search?q=track%3ALook+Ba&type=track
# https://api.spotify.com/v1/search?q=artist%3AFabolous+featuring+Nate+Dogg+track%3ACan%27t+Deny+It&type=track
# https://api.spotify.com/v1/search?q=track%3ACan%27t+&type=track
# https://api.spotify.com/v1/search?q=artist%3ADJ+Amaze+track%3AI+Wanna+Rock&type=track
# https://api.spotify.com/v1/search?q=track%3AI+Wann&type=track
# https://api.spotify.com/v1/search?q=artist%3A50+Cent+track%3AGet+Up&type=track
# https://api.spotify.com/v1/search?q=artist%3ASwizz+Beatz+track%3AIt%27s+Me+Bitches&type=track
# https://api.spotify.com/v1/search?q=artist%3ALL+Cool+J+track%3AJingling+Baby+%28Remixed+But+Still+Jingling%29&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Notorious+B.I.G.+featuring+Diddy%2C+Nelly%2C+Jagged+Edge%2C+and+Avery+Storm+track%3ANasty+Girl&type=track
# https://api.spotify.com/v1/search?q=track%3ANasty&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Notorious+B.I.G.+track%3ANasty+Boy&type=track
# https://api.spotify.com/v1/search?q=artist%3ATrina+featuring+Kase%2C+Deuce+Poppi+and+Trick+Daddy+track%3APull+Over+%28Remix%29&type=track
# https://api.spotify.com/v1/search?q=track%3APull+Ove&type=track
# https://api.spotify.com/v1/search?q=artist%3AJibbs+featuring+Lloyd+track%3AThe+Dedication+%28Ay+DJ%29&type=track
# https://api.spotify.com/v1/search?q=track%3AThe+Dedicat&type=track
# https://api.spotify.com/v1/search?q=artist%3ADJ+Laz+featuring+Flo+Rida+and+Casely+track%3AMove+Shake+Drop&type=track
# https://api.spotify.com/v1/search?q=track%3AMove+Sh&type=track
# https://api.spotify.com/v1/search?q=artist%3ABlack+Box+track%3AEverybody+Everybody&type=track
# https://api.spotify.com/v1/search?q=artist%3ADennis+Coffey+and+the+Detroit+Guitar+Band+track%3AScorpio&type=track
# https://api.spotify.com/v1/search?q=artist%3ABasement+Jaxx+track%3AWhere%27s+Your+Head+At%3F&type=track
# https://api.spotify.com/v1/search?q=artist%3AJordan+Knight+track%3AGive+It+to+You&type=track
# https://api.spotify.com/v1/search?q=artist%3ATravis+Porter+track%3AGo+Shorty+Go&type=track
# https://api.spotify.com/v1/search?q=track%3AGo+Sho&type=track
# https://api.spotify.com/v1/search?q=artist%3AJohn+Lennon+track%3AImagine&type=track
# https://api.spotify.com/v1/search?q=artist%3ADavid+Banner+featuring+Chris+Brown+track%3AGet+Like+Me&type=track
# https://api.spotify.com/v1/search?q=track%3AGet+L&type=track
# https://api.spotify.com/v1/search?q=artist%3AKid+Cudi+featuring+Kanye+West+and+Common+track%3AMake+Her+Say%22+%28portion+sampled+samples+%22In+the+Morning+Time%22+by+Tramaine%29&type=track
# https://api.spotify.com/v1/search?q=track%3AMake+Her+Say%22+%28portion+sampled+sampl&type=track
# https://api.spotify.com/v1/search?q=track%3AMake+Her+Say&type=track
# https://api.spotify.com/v1/search?q=artist%3ADiddy+featuring+Christina+Aguilera+track%3ATell+Me&type=track
# https://api.spotify.com/v1/search?q=track%3ATel&type=track
# https://api.spotify.com/v1/search?q=artist%3AMarva+Whitney+track%3AUnwind+Yourself&type=track
# https://api.spotify.com/v1/search?q=artist%3AKrave+featuring+Flo+Rida%2C+Pitbull%2C+and+Lil+Jon+track%3AGo+Crazy&type=track
# https://api.spotify.com/v1/search?q=track%3AGo+C&type=track
# https://api.spotify.com/v1/search?q=artist%3AT.I.+track%3ARubberband+Man&type=track
# https://api.spotify.com/v1/search?q=artist%3ARosalind+Rice+featuring+French+Montana+track%3AHustler&type=track
# https://api.spotify.com/v1/search?q=track%3AHus&type=track
# https://api.spotify.com/v1/search?q=artist%3AThe+Edgar+Winter+Group+track%3AFrankenstein&type=track
# https://api.spotify.com/v1/search?q=artist%3ADMX+featuring+Sheek+Louch+track%3AGet+at+Me+Dog&type=track
# https://api.spotify.com/v1/search?q=track%3AGet+at&type=track

# %%
songs_df
# Out:
#                                              artist  \
# 0                                     Black Sabbath
# 1                                          The Pack
# 2                                            M.I.A.
# 3                                       Jimmy Smith
# 4                                          Dorrough
# ..                                              ...
# 341  Krave featuring Flo Rida, Pitbull, and Lil Jon
# 342                                            T.I.
# 343          Rosalind Rice featuring French Montana
# 344                          The Edgar Winter Group
# 345                       DMX featuring Sheek Louch
#
#                                           track  \
# 0                                      War Pigs
# 1                            This Shit Slappin'
# 2                                  Paper Planes
# 3    I'm Gonna Love You Just a Little More Babe
# 4                           Ice Cream Paint Job
# ..                                          ...
# 341                                    Go Crazy
# 342                              Rubberband Man
# 343                                     Hustler
# 344                                Frankenstein
# 345                               Get at Me Dog
#
#                                 track_uri
# 0    spotify:track:2rd9ETlulTbz6BYZcdvIE1
# 1    spotify:track:4IeUAegXVbETb7FpgNDnSM
# 2    spotify:track:1ixbwbeBi5ufN4noUKmW5a
# 3    spotify:track:1uu0es5Bu7orSWkqS5rXp7
# 4    spotify:track:57QFOU3f7O0gDLadxv5z8w
# ..                                    ...
# 341  spotify:track:2Y0wPrPQBrGhoLn14xRYCG
# 342  spotify:track:6jN49cPLhJxsIUaoJ0yroP
# 343  spotify:track:5ErtQGRKEibK2WHaA729O8
# 344  spotify:track:2l0Z9fY1E8Bep8opmhmDhq
# 345  spotify:track:1OKQIvaO7yn7R2BpdUFG7D
#
# [346 rows x 3 columns]

# %%
songs_df[songs_df['track_uri'] == ""]
# Out:
#        artist                 track track_uri
# 144  Fabolous  Young'n (Holla Back)

# %% [markdown]
# ## Collected all spotify trackuris except for one

# %%
songs_df.to_csv('./data/tracks_uri.csv')
